# %% [markdown]
# # FRED-MD Benchmark Validation
#
# Validates two specific values from the **FRED-MD row** of the Chronos paper results table:
#
# | Model | Paper MASE |
# |---|---|
# | Chronos T5-Small (zero-shot) | **0.496** |
# | Seasonal Naive | **1.101** |
#
# ---
#
# **Evaluation protocol (paper Benchmark II / Appendix D)**
#
# - **Dataset**: FRED-MD — 107 monthly macro-economic series, McCracken-Ng transformed (differenced/log-transformed for stationarity)
# - **Test set**: last H = 12 observations of each series (held out completely)
# - **Context**: all prior observations (truncated to 512 tokens for Chronos)
# - **Metric**: MASE with seasonal period S = 12, denominator computed on the training window only, averaged across all 107 series
# - **Chronos point forecast**: median (0.5-quantile) of probabilistic samples

# %%
print("hello")
# Out:
# hello

# %%
import sys
import warnings
import numpy as np
import pandas as pd
import torch
from tqdm.auto import tqdm
from pathlib import Path
from chronos import ChronosPipeline
from statsforecast import StatsForecast
from statsforecast.models import SeasonalNaive, AutoARIMA
from tsfm_public.toolkit.util import convert_tsf_to_dataframe
import matplotlib.pyplot as plt 

warnings.filterwarnings('ignore')
print('Imports OK')
# Out:
# Imports OK

# %%
TSF_PATH        = 'data/fred_md_dataset.tsf'
HORIZON         = 12    # months to forecast
SEASONALITY     = 12    # monthly seasonality for MASE denominator
CHRONOS_MODEL   = 'amazon/chronos-t5-small'
CHRONOS_CONTEXT = 512   # max context tokens for T5-Small

# Paper's reported MASE values (FRED-MD row)
PAPER_CHRONOS_SMALL = 0.496
PAPER_SNAIVE        = 1.101

# %% [markdown]
# ## 1. Data
#
# `fred_md_dataset.tsf` is the Monash Time Series Repository version of the FRED-MD database. It contains 107 monthly series of US macro-economic indicators transformed via the McCracken-Ng protocol (differencing and log-transforms applied per variable group to achieve approximate stationarity). All series are equal-length and have no missing values.
#
# `convert_tsf_to_dataframe` (from `tsfm_public.toolkit.util`) parses the `.tsf` file into a DataFrame where each row is one series with columns `series_name`, `start_timestamp`, and `series_value` (array).

# %%
df, freq, *_ = convert_tsf_to_dataframe(TSF_PATH)

series_names  = df['series_name'].tolist()
series_values = [np.array(row['series_value'], dtype=float) for _, row in df.iterrows()]
starts        = [pd.to_datetime(str(row['start_timestamp']).split()[0]) for _, row in df.iterrows()]

lengths = [len(v) for v in series_values]
print(f'Series loaded  : {len(series_names)}')
print(f'Frequency      : {freq}')
print(f'Series length  : min={min(lengths)}, max={max(lengths)}')
print(f'Example        : {series_names[0]} | {lengths[0]} obs | starts {starts[0].date()}')
# Out:
# Series loaded  : 107
# Frequency      : monthly
# Series length  : min=728, max=728
# Example        : T1 | 728 obs | starts 1959-01-01

# %% [markdown]
# ## 2. Train / Test Split
#
# The paper holds out the **last H = 12 observations** of each series as the test set and uses everything before as context. No shuffling, no rolling window — a single fixed split per series.

# %%
trains = [v[:-HORIZON] for v in series_values]
tests  = [v[-HORIZON:] for v in series_values]

print(f'Context length : {len(trains[0])} obs (example series)')
print(f'Test length    : {len(tests[0])} obs per series')
assert all(len(t) == HORIZON for t in tests), 'All test sets must have exactly H observations'
# Out:
# Context length : 716 obs (example series)
# Test length    : 12 obs per series

# %% [markdown]
# ## 3. Chronos T5-Small (Zero-Shot)
#
# Chronos is a pretrained probabilistic forecasting model based on T5. **Zero-shot** means it is used directly with no fine-tuning on FRED-MD — only the context window is passed in.
#
# `pipeline.predict(context, prediction_length=H)` returns a tensor of shape `(1, num_samples, H)` — a distribution over H-step forecasts represented as Monte Carlo samples. We collapse the sample dimension by taking the **median (0.5-quantile)**, following the paper's stated approach for computing MASE from probabilistic forecasters.
#
# The context is capped at `CHRONOS_CONTEXT = 512` tokens (the model's effective input limit).

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
dtype  = torch.bfloat16 if device == 'cuda' else torch.float32
pipeline = ChronosPipeline.from_pretrained(
    CHRONOS_MODEL, device_map=device, torch_dtype=dtype,
)
print(f'Loaded {CHRONOS_MODEL} on {device}')
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loaded amazon/chronos-t5-small on cpu

# %%
chronos_forecasts = []

for train in tqdm(trains, desc='Chronos T5-Small'):
    ctx     = train[-CHRONOS_CONTEXT:] if len(train) > CHRONOS_CONTEXT else train
    context = torch.tensor(np.array(ctx, dtype=np.float32))
    forecast = pipeline.predict(context, prediction_length=HORIZON)  # (1, num_samples, H)
    samples  = forecast[0, :, :].detach().cpu().numpy()              # (num_samples, H)
    median   = np.quantile(samples, 0.50, axis=0)                    # (H,)
    chronos_forecasts.append(median)

print(f'Generated {len(chronos_forecasts)} forecasts, each of length {len(chronos_forecasts[0])}')
# Out:
# Chronos T5-Small:   0%|          | 0/107 [00:00<?, ?it/s]
# Generated 107 forecasts, each of length 12

# %% [markdown]
# ## 4. Seasonal Naive
#
# The seasonal naive forecast repeats the value from the same month in the previous year:
#
# $$\hat{x}_{t} = x_{t - S}, \quad S = 12$$
#
# For a 12-month horizon this is simply the last 12 training observations (in the same calendar-month order). We use `statsforecast.models.SeasonalNaive` which implements this exactly. It requires no fitting beyond storing the last S values of the training series.

# %%
sf_frames = []
for name, train, start in zip(series_names, trains, starts):
    dates = pd.date_range(start=start, periods=len(train), freq='MS')
    sf_frames.append(pd.DataFrame({
        'unique_id': name,
        'ds': dates,
        'y': train.astype(float),
    }))
train_df = pd.concat(sf_frames, ignore_index=True)

sf = StatsForecast(
    models=[SeasonalNaive(season_length=SEASONALITY)],
    freq='MS',
    n_jobs=-1,
)
sf.fit(train_df)
pred_df = sf.predict(h=HORIZON)

snaive_forecasts = [
    pred_df[pred_df['unique_id'] == name]['SeasonalNaive'].values
    for name in series_names
]
print(f'Generated {len(snaive_forecasts)} forecasts, each of length {len(snaive_forecasts[0])}')
# Out:
# Generated 107 forecasts, each of length 12

# %% [markdown]
# ## 5. Last Value (Naive)
#
# The last-value baseline repeats the final training observation for all H forecast steps:
#
# $$\hat{x}_{t} = x_{C}, \quad t = C+1, \ldots, C+H$$
#
# This is the simplest possible forecast and serves as a lower-bound sanity check — any reasonable model should beat it.

# %%
last_value_forecasts = [
    np.full(HORIZON, train[-1])
    for train in trains
]
print(f'Generated {len(last_value_forecasts)} forecasts, each of length {len(last_value_forecasts[0])}')
# Out:
# Generated 107 forecasts, each of length 12

# %% [markdown]
# ## 6. AutoARIMA
#
# AutoARIMA automatically selects the ARIMA(p, d, q) order for each series by minimising AICc over a search grid. It is a strong classical baseline that adapts to each series' stationarity and autocorrelation structure without manual tuning.
#
# We use `statsforecast.models.AutoARIMA` with seasonal period 12 (monthly), run in parallel across all 107 series.

# %%
sf_aa = StatsForecast(
    models=[AutoARIMA(season_length=SEASONALITY)],
    freq='MS',
    n_jobs=-1,
)
sf_aa.fit(train_df)
pred_aa_df = sf_aa.predict(h=HORIZON)

autoarima_forecasts = [
    pred_aa_df[pred_aa_df['unique_id'] == name]['AutoARIMA'].values
    for name in series_names
]
print(f'Generated {len(autoarima_forecasts)} AutoARIMA forecasts, each of length {len(autoarima_forecasts[0])}')
# Out:
# Generated 107 AutoARIMA forecasts, each of length 12

# %% [markdown]
# ## 7. AutoARIMA (BIC)
#
# Same automatic order selection as above, but using **BIC** (`ln(n) · k`) instead of the default AICc (`2k`) penalty. BIC penalises extra parameters more heavily as series length grows, so it tends to select sparser, lower-order ARIMA models — useful to see whether the simpler model generalises better on these macro series.

# %%
sf_aa_bic = StatsForecast(
    models=[AutoARIMA(season_length=SEASONALITY, ic='bic')],
    freq='MS',
    n_jobs=-1,
)
sf_aa_bic.fit(train_df)
pred_aa_bic_df = sf_aa_bic.predict(h=HORIZON)

autoarima_bic_forecasts = [
    pred_aa_bic_df[pred_aa_bic_df['unique_id'] == name]['AutoARIMA'].values
    for name in series_names
]
print(f'Generated {len(autoarima_bic_forecasts)} AutoARIMA-BIC forecasts, each of length {len(autoarima_bic_forecasts[0])}')
# Out:
# Generated 107 AutoARIMA-BIC forecasts, each of length 12

# %% [markdown]
# ## 5. MASE
#
# The paper uses the **Mean Absolute Scaled Error** with seasonal period S = 12. For each series i:
#
# $$\text{MASE}_i = \frac{\frac{1}{H}\sum_{t=C+1}^{C+H}|\hat{x}_{i,t} - x_{i,t}|}{\frac{1}{C-S}\sum_{t=1}^{C-S}|x_{i,t+S} - x_{i,t}|}$$
#
# where C = T − H is the context length. The denominator is the mean absolute error of a seasonal naive forecast **on the training window only** (never touches the test set). The final score is the simple mean across all 107 series:
#
# $$\text{FRED-MD MASE} = \frac{1}{107}\sum_{i=1}^{107} \text{MASE}_i$$

# %%
def mase_score(forecast: np.ndarray, actual: np.ndarray, history: np.ndarray, s: int = 12) -> float:
    mae   = np.mean(np.abs(forecast - actual))
    scale = np.mean(np.abs(history[s:] - history[:-s]))
    return float(mae / scale) if scale > 0 else np.nan


chronos_mases = [
    mase_score(f, t, h, SEASONALITY)
    for f, t, h in zip(chronos_forecasts, tests, trains)
]
snaive_mases = [
    mase_score(f, t, h, SEASONALITY)
    for f, t, h in zip(snaive_forecasts, tests, trains)
]
last_value_mases = [
    mase_score(f, t, h, SEASONALITY)
    for f, t, h in zip(last_value_forecasts, tests, trains)
]
autoarima_mases = [
    mase_score(f, t, h, SEASONALITY)
    for f, t, h in zip(autoarima_forecasts, tests, trains)
]
autoarima_bic_mases = [
    mase_score(f, t, h, SEASONALITY)
    for f, t, h in zip(autoarima_bic_forecasts, tests, trains)
]

avg_chronos        = float(np.nanmean(chronos_mases))
avg_snaive         = float(np.nanmean(snaive_mases))
avg_last_value     = float(np.nanmean(last_value_mases))
avg_autoarima      = float(np.nanmean(autoarima_mases))
avg_autoarima_bic  = float(np.nanmean(autoarima_bic_mases))

print(f'Chronos T5-Small  MASE : {avg_chronos:.4f}  (paper: {PAPER_CHRONOS_SMALL})')
print(f'Seasonal Naive    MASE : {avg_snaive:.4f}  (paper: {PAPER_SNAIVE})')
print(f'Last Value        MASE : {avg_last_value:.4f}')
print(f'AutoARIMA (AICc)  MASE : {avg_autoarima:.4f}')
print(f'AutoARIMA (BIC)   MASE : {avg_autoarima_bic:.4f}')
# Out:
# Chronos T5-Small  MASE : 0.4813  (paper: 0.496)
# Seasonal Naive    MASE : 1.1008  (paper: 1.101)
# Last Value        MASE : 0.6219
# AutoARIMA (AICc)  MASE : 0.4719
# AutoARIMA (BIC)   MASE : 0.4888

# %% [markdown]
# ## 6. Results

# %%
results = pd.DataFrame({
    'Model':         ['Chronos T5-Small (zero-shot)', 'Seasonal Naive', 'Last Value', 'AutoARIMA (AICc)', 'AutoARIMA (BIC)'],
    'Computed MASE': [avg_chronos, avg_snaive, avg_last_value, avg_autoarima, avg_autoarima_bic],
    'Paper MASE':    [PAPER_CHRONOS_SMALL, PAPER_SNAIVE, float('nan'), float('nan'), float('nan')],
    'Difference':    [avg_chronos - PAPER_CHRONOS_SMALL, avg_snaive - PAPER_SNAIVE, float('nan'), float('nan'), float('nan')],
}).set_index('Model')

results.style.format({
    'Computed MASE': '{:.4f}',
    'Paper MASE':    lambda v: f'{v:.4f}' if not np.isnan(v) else '—',
    'Difference':    lambda v: f'{v:+.4f}' if not np.isnan(v) else '—',
}).background_gradient(subset=['Computed MASE'], cmap='RdYlGn_r', axis=0)
# Out:
# <style type="text/css">
# #T_8300c_row0_col0 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_8300c_row1_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_8300c_row2_col0 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_8300c_row3_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8300c_row4_col0 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8300c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8300c_level0_col0" class="col_heading level0 col0" >Computed MASE</th>
#       <th id="T_8300c_level0_col1" class="col_heading level0 col1" >Paper MASE</th>
#       <th id="T_8300c_level0_col2" class="col_heading level0 col2" >Difference</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8300c_level0_row0" class="row_heading level0 row0" >Chronos T5-Small (zero-shot)</th>
#       <td id="T_8300c_row0_col0" class="data row0 col0" >0.4813</td>
#       <td id="T_8300c_row0_col1" class="data row0 col1" >0.4960</td>
#       <td id="T_8300c_row0_col2" class="data row0 col2" >-0.0147</td>
#     </tr>
#     <tr>
#       <th id="T_8300c_level0_row1" class="row_heading level0 row1" >Seasonal Naive</th>
#       <td id="T_8300c_row1_col0" class="data row1 col0" >1.1008</td>
#       <td id="T_8300c_row1_col1" class="data row1 col1" >1.1010</td>
#       <td id="T_8300c_row1_col2" class="data row1 col2" >-0.0002</td>
#     </tr>
#     <tr>
#       <th id="T_8300c_level0_row2" class="row_heading level0 row2" >Last Value</th>
#       <td id="T_8300c_row2_col0" class="data row2 col0" >0.6219</td>
#       <td id="T_8300c_row2_col1" class="data row2 col1" >—</td>
#       <td id="T_8300c_row2_col2" class="data row2 col2" >—</td>
#     </tr>
#     <tr>
#       <th id="T_8300c_level0_row3" class="row_heading level0 row3" >AutoARIMA (AICc)</th>
#       <td id="T_8300c_row3_col0" class="data row3 col0" >0.4719</td>
#       <td id="T_8300c_row3_col1" class="data row3 col1" >—</td>
#       <td id="T_8300c_row3_col2" class="data row3 col2" >—</td>
#     </tr>
#     <tr>
#       <th id="T_8300c_level0_row4" class="row_heading level0 row4" >AutoARIMA (BIC)</th>
#       <td id="T_8300c_row4_col0" class="data row4 col0" >0.4888</td>
#       <td id="T_8300c_row4_col1" class="data row4 col1" >—</td>
#       <td id="T_8300c_row4_col2" class="data row4 col2" >—</td>
#     </tr>
#   </tbody>
# </table>

# %%
rng = np.random.default_rng(42)
N_BOOT = 1000
N_SERIES = 107  # resample all 107 series with replacement each iteration (~63% unique per draw)

all_mases = {
    'Chronos T5-Small': chronos_mases,
    'Seasonal Naive':   snaive_mases,
    'Last Value':       last_value_mases,
    'AutoARIMA (AICc)': autoarima_mases,
    'AutoARIMA (BIC)':  autoarima_bic_mases,
}

boot_rows = []
for model, mases in all_mases.items():
    arr = np.array(mases, dtype=float)
    arr = arr[~np.isnan(arr)]
    boot_means = [np.mean(rng.choice(arr, size=N_SERIES, replace=True)) for _ in range(N_BOOT)]
    boot_rows.append({
        'Model': model,
        'Mean MASE': np.mean(arr),
        'CI lower (5%)':  np.percentile(boot_means, 5),
        'CI upper (95%)': np.percentile(boot_means, 95),
    })

boot_df = pd.DataFrame(boot_rows).set_index('Model')

fig, ax = plt.subplots(figsize=(8, 4))
for i, (model, row) in enumerate(boot_df.iterrows()):
    ax.errorbar(
        x=row['Mean MASE'], y=i,
        xerr=[[row['Mean MASE'] - row['CI lower (5%)']],
              [row['CI upper (95%)'] - row['Mean MASE']]],
        fmt='o', capsize=5, linewidth=1.5,
    )
ax.set_yticks(range(len(boot_df)))
ax.set_yticklabels(boot_df.index)
ax.axvline(1.0, color='black', ls='--', lw=1, label='Seasonal Naive baseline')
ax.set_xlabel('MASE (lower is better)')
ax.set_title(f'Mean MASE with 90% bootstrap CI ({N_BOOT} resamples, n={N_SERIES} series each)')
ax.legend(fontsize=8)
ax.grid(True, axis='x')
plt.tight_layout()
plt.show()

display(boot_df.style.format('{:.4f}').background_gradient(subset=['Mean MASE'], cmap='RdYlGn_r', axis=0))
# Out:
# <style type="text/css">
# #T_29c1c_row0_col0 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_29c1c_row1_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_29c1c_row2_col0 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_29c1c_row3_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_29c1c_row4_col0 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_29c1c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29c1c_level0_col0" class="col_heading level0 col0" >Mean MASE</th>
#       <th id="T_29c1c_level0_col1" class="col_heading level0 col1" >CI lower (5%)</th>
#       <th id="T_29c1c_level0_col2" class="col_heading level0 col2" >CI upper (95%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29c1c_level0_row0" class="row_heading level0 row0" >Chronos T5-Small</th>
#       <td id="T_29c1c_row0_col0" class="data row0 col0" >0.4813</td>
#       <td id="T_29c1c_row0_col1" class="data row0 col1" >0.4254</td>
#       <td id="T_29c1c_row0_col2" class="data row0 col2" >0.5428</td>
#     </tr>
#     <tr>
#       <th id="T_29c1c_level0_row1" class="row_heading level0 row1" >Seasonal Naive</th>
#       <td id="T_29c1c_row1_col0" class="data row1 col0" >1.1008</td>
#       <td id="T_29c1c_row1_col1" class="data row1 col1" >0.9240</td>
#       <td id="T_29c1c_row1_col2" class="data row1 col2" >1.2947</td>
#     </tr>
#     <tr>
#       <th id="T_29c1c_level0_row2" class="row_heading level0 row2" >Last Value</th>
#       <td id="T_29c1c_row2_col0" class="data row2 col0" >0.6219</td>
#       <td id="T_29c1c_row2_col1" class="data row2 col1" >0.5166</td>
#       <td id="T_29c1c_row2_col2" class="data row2 col2" >0.7301</td>
#     </tr>
#     <tr>
#       <th id="T_29c1c_level0_row3" class="row_heading level0 row3" >AutoARIMA (AICc)</th>
#       <td id="T_29c1c_row3_col0" class="data row3 col0" >0.4719</td>
#       <td id="T_29c1c_row3_col1" class="data row3 col1" >0.3967</td>
#       <td id="T_29c1c_row3_col2" class="data row3 col2" >0.5602</td>
#     </tr>
#     <tr>
#       <th id="T_29c1c_level0_row4" class="row_heading level0 row4" >AutoARIMA (BIC)</th>
#       <td id="T_29c1c_row4_col0" class="data row4 col0" >0.4888</td>
#       <td id="T_29c1c_row4_col1" class="data row4 col1" >0.3980</td>
#       <td id="T_29c1c_row4_col2" class="data row4 col2" >0.5993</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 7. Summary
#
# The table above compares our computed MASE against the paper's reported values. Small differences (< 0.01) are expected due to:
#
# - **Chronos sampling stochasticity** — the paper may have used a fixed random seed not published alongside the results.
# - **Exact series count** — the paper may include or exclude a small number of series with very short histories or extreme outliers.
# - **Context truncation** — we cap at 512 tokens; the paper uses the same limit for T5-Small but the exact tokenisation may differ slightly.
#
# A Difference of ≈ 0 for Seasonal Naive (which is deterministic) confirms the data split and MASE formula are correctly implemented.
